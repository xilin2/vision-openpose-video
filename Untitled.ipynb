# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# %run -i 'analysis.py'
# Out:
# Layer cross-validation results
# ----------
# Layer cross-validation results
# ----------
# 0.21613130411083784
# 0.23935075148563026
# 0.10455373110202579
# 0.1062464277491097
# 0.21733647636373526
# 0.15848062628565057
# 0.06543939381262562
# 0.0653754736869646
# > /mnt/projects/projects/vision-openpose-video/analysis.py(745)<module>()
# -> complete_pose_scores = {}
